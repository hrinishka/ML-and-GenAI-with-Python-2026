# %% [markdown]
# <a href="https://colab.research.google.com/github/hrinishka/ML-and-GenAI-with-Python-2026/blob/main/Assignments/Assignment_2/Hrinishka_07001012025/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sum of First 10 Natural Numbers
sum = 0
for i in range(1, 11):
    sum += i
print("Sum =", sum)
# Out:
# Sum = 55

# %%
# Factorial Program
num = int(input("Enter a number: "))
factorial = 1
for i in range(1, num + 1):
    factorial *= i
print("Factorial =", factorial)
# Out:
# Enter a number: 65
# Factorial = 8247650592082470666723170306785496252186258551345437492922123134388955774976000000000000000

# %%
# Fibonacci Series
n = int(input("Enter number of terms: "))
a = 0
b = 1
print("Fibonacci Series:")
for i in range(n):
    print(a, end=" ")
    temp = a + b
    a = b
    b = temp
# Out:
# Enter number of terms: 5
# Fibonacci Series:
# 0 1 1 2 3

# %%
# Largest Among Three Numbers
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
if a >= b and a >= c:
    print("Largest Number =", a)
elif b >= a and b >= c:
    print("Largest Number =", b)
else:
    print("Largest Number =", c)
# Out:
# Enter first number: 56
# Enter second number: 87
# Enter third number: 90
# Largest Number = 90

# %%
# Student Result System
name = input("Enter Student Name: ")
subjects = int(input("Enter Number of Subjects: "))
total = 0
for i in range(1, subjects + 1):
    marks = float(input(f"Enter Marks of Subject {i}: "))
    total += marks
percentage = total / subjects

# Grade Calculation
if percentage >= 90:
    grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 50:
    grade = "D"
else:
    grade = "Fail"
print("\nRESULT\n")
print("Student Name :", name)
print("Total Marks :", total)
print("Percentage :", percentage)
print("Grade :", grade)
# Out:
# Enter Student Name: Hrinishka
# Enter Number of Subjects: 3
# Enter Marks of Subject 1: 89
# Enter Marks of Subject 2: 78
# Enter Marks of Subject 3: 76
#
# RESULT
#
# Student Name : Hrinishka
# Total Marks : 243.0
# Percentage : 81.0
# Grade : A
